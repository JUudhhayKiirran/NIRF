# %% [markdown]
# <a href="https://colab.research.google.com/github/JUudhhayKiirran/NIRF/blob/main/NIRF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 0.1 **Importing** the **libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 0.2 Importing the **dataset**

# %%
dataset = pd.read_excel('/content/NIRF_1-100_2022.xlsx')
dataset
# Out:
#                                   Name of the college  Rank  Score  \
# 0                                       Miranda House     1  78.00
# 1                                               Hindu     2  71.86
# 2                  PSGR Krishnammal College for Women     6  70.68
# 3                      Atma Ram Sanatan Dharm College     7  70.46
# 4                                St. Xavier's College     8  69.54
# 5                     Ramakrishna Mission Vidyamandir     9  69.24
# 6                               St. Stephen's College    11  68.30
# 7                        Shri Ram College of Commerce    12  67.89
# 8                                    Hans Raj College    14  67.38
# 9                                  Lady Irwin College    16  66.25
# 10                           Madras Christian College    17  65.72
# 11                       Acharya Narendra Dev College    18  65.46
# 12                    PSG College of Arts and Science    20  64.56
# ...

# %% [markdown]
# # 0.3 Check if any null **value**

# %%
dataset.isna().sum()
# Out:
# Name of the college                                      0
# Rank                                                     0
# Score                                                    0
# Total student sanctioned                                 0
# Total students enrolled                                  0
# Secured_SS                                               0
# Full time regular faculty                                0
# others                                                   0
# Adhoc Faculty                                            0
# Secured_FSR                                              0
# Experience up to 8 years                                 0
# Experience from 8 to 15 years                            0
# Experience  >= 15 years                                  0
# Faculty with PHD,Net and SET                             0
# Secured_FQE                                              0
# Annual Capital Expenditure per student                   0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 46 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Name of the college                                    51 non-null     object
#  1   Rank                                                   51 non-null     int64
#  2   Score                                                  51 non-null     float64
#  3   Total student sanctioned                               51 non-null     int64
#  4   Total students enrolled                                51 non-null     int64
#  5   Secured_SS                                             51 non-null     float64
#  6   Full time regular faculty                              51 non-null     int64
#  7   others                                                 51 non-null     int64
# ...

# %% [markdown]
# # 0.4 Split into X & y

# %%
#'Name of the college',
X = df=pd.DataFrame(dataset,columns=['Total student sanctioned','Total students enrolled','Secured_SS','Full time regular faculty','others','Adhoc Faculty','Secured_FSR','Experience up to 8 years','Experience from 8 to 15 years','Experience  >= 15 years','Faculty with PHD,Net and SET','Secured_FQE','Average Captial','Average Expenditure','Secured_FRU'])
X
# Out:
#     Total student sanctioned  Total students enrolled  Secured_SS  \
# 0                       4349                     5065       18.00
# 1                       3442                     4205       16.00
# 2                       8090                     7712       17.16
# 3                       4150                     4451       16.00
# 4                       8181                     8038       17.24
# 5                        702                      696        7.93
# 6                       1380                     1382       10.00
# 7                       2325                     2870       12.00
# 8                       4973                     6274       18.00
# 9                       1498                     1484        9.91
# 10                      7010                     6647       17.07
# 11                      2123                     2035        9.77
# 12                     13622                    12741       18.56
# ...

# %%
y = dataset['Total TLR(100)']
y
# Out:
# 0     78.35
# 1     71.62
# 2     74.21
# 3     74.18
# 4     65.30
# 5     74.98
# 6     75.90
# 7     70.81
# 8     63.43
# 9     81.16
# 10    59.10
# 11    76.92
# 12    63.30
# 13    65.50
# 14    73.65
# 15    75.61
# 16    76.18
# 17    78.00
# 18    65.78
# 19    56.92
# 20    78.91
# 21    71.07
# 22    72.21
# 23    64.94
# 24    60.40
# 25    55.20
# 26    67.31
# 27    74.35
# 28    65.33
# 29    62.21
# 30    52.71
# 31    73.56
# 32    58.20
# 33    45.35
# 34    67.36
# 35    65.96
# 36    68.96
# 37    70.82
# 38    63.39
# 39    66.04
# 40    64.89
# 41    60.67
# 42    62.47
# 43    66.71
# 44    64.26
# 45    64.45
# 46    57.50
# 47    68.04
# 48    69.68
# 49    64.40
# 50    66.20
# Name: Total TLR(100), dtype: float64

# %% [markdown]
# # 0.6 Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 2509)

# %% [markdown]
# # 1. Training the Multiple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-19f7ef69ea28> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(X_train, y_train)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
# ...
